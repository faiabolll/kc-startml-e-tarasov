# %%
import warnings
warnings.filterwarnings('ignore')

### Установим красивые дефолтные настройки
### Может быть лень постоянно прописывать
### У графиков параметры цвета, размера, шрифта
### Можно положить их в словарь дефолтных настроек

import matplotlib as mlp

mlp.rcParams['lines.linewidth'] = 5
mlp.rcParams['xtick.major.size'] = 20
mlp.rcParams['xtick.major.width'] = 5
mlp.rcParams['xtick.labelsize'] = 20
mlp.rcParams['xtick.color'] = '#FF5533'

mlp.rcParams['ytick.major.size'] = 20
mlp.rcParams['ytick.major.width'] = 5
mlp.rcParams['ytick.labelsize'] = 20
mlp.rcParams['ytick.color'] = '#FF5533'

mlp.rcParams['axes.labelsize'] = 20
mlp.rcParams['axes.titlesize'] = 20
mlp.rcParams['axes.titlecolor'] = '#00B050'
mlp.rcParams['axes.labelcolor'] = '#00B050'

# %% [markdown]
# ### Предсказание отклика банковских клиентов на основе данных маркетинговой кампании португальских банков

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.max_columns = 500

df = pd.read_csv("banking.csv")
df.shape
# Out:
# (41188, 21)

# %%
df.head()
# Out:
#    age          job  marital          education  default housing loan  \
# 0   44  blue-collar  married           basic.4y  unknown     yes   no
# 1   53   technician  married            unknown       no      no   no
# 2   28   management   single  university.degree       no     yes   no
# 3   39     services  married        high.school       no      no   no
# 4   55      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  duration  campaign  pdays  previous  \
# 0  cellular   aug         thu       210         1    999         0
# 1  cellular   nov         fri       138         1    999         0
# 2  cellular   jun         thu       339         3      6         2
# 3  cellular   apr         fri       185         2    999         0
# 4  cellular   aug         fri       137         1      3         1
#
#       poutcome  emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 0  nonexistent           1.4          93.444          -36.1      4.963
# 1  nonexistent          -0.1          93.200          -42.0      4.021
# 2      success          -1.7          94.055          -39.8      0.729
# 3  nonexistent          -1.8          93.075          -47.1      1.405
# 4      success          -2.9          92.201          -31.4      0.869
#
#    nr_employed  y
# 0       5228.1  0
# 1       5195.8  0
# 2       4991.6  1
# 3       5099.1  0
# 4       5076.2  1

# %% [markdown]
# <dl>
# <dt> Описание колонок:
# <dd>age - возраст клиента </dd>
# <dd>job - тип работы </dd>
# <dd>marital - статус замужества</dd>
# <dd>education - степень образования </dd>
# <dd>default - дефолтил ли клиент? </dd>
# <dd>housing - есть ли жилищный кредит? </dd>
# <dd>loan - есть ли потребительский кредит? </dd>
# <dd>contact - тип коммуникации </dd>
# <dd>month - месяц последнего контакта </dd>
# <dd>day_of_week - день недели последнего контакта </dd>
# <dd>duration - длительность последнего звонка - стоит убрать при обучении модели </dd>
# <dd>campaign - количество звонков в течение маркетинговой кампании </dd>
# <dd>pdays - как давно не было коммуникации с клиентом, относительно предыдущей маркетинговой кампании </dd>
# <dd>previous - количество звоноков до текущей маркетинговой компании </dd>
# <dd>poutcome - результат предыдущей маркентинговой кампании относительно выбранного клиента </dd>
# <dd>emp.var.rate - коэффициент вариации безработицы (quarterly) </dd>
# <dd>cons.price.idx - индекс потребительских цен (monthly) </dd>
# <dd>cons.conf.idx: - индекс потребительской уверенности (monthly) </dd>
# <dd>euribor3m - межбанковская европейская ставка предложения по трехмесячному займу (daily) </dd>
# <dd>nr.employed - количество занятых </dd>
# <dd>y - таргетная переменная: взял ли клиент депозит </dd>
# </dl>
#
# **Наша целевая переменная - взял ли клиент депозит.**

# %%
### Уберем колонку duration

df = df.drop('duration', axis=1)

# %%
### Посмотрим на некатегориальные колонки

numeric_columns = df.loc[:,df.dtypes!=object].columns
df.loc[:,df.dtypes!=object].head(2)
# Out:
#    age  campaign  pdays  previous  emp_var_rate  cons_price_idx  \
# 0   44         1    999         0           1.4          93.444
# 1   53         1    999         0          -0.1          93.200
#
#    cons_conf_idx  euribor3m  nr_employed  y
# 0          -36.1      4.963       5228.1  0
# 1          -42.0      4.021       5195.8  0

# %%
### Посмотрим на категориальные колонки

categorical_columns = df.loc[:,df.dtypes==object].columns
df.loc[:,df.dtypes==object].head(2)
# Out:
#            job  marital education  default housing loan   contact month  \
# 0  blue-collar  married  basic.4y  unknown     yes   no  cellular   aug
# 1   technician  married   unknown       no      no   no  cellular   nov
#
#   day_of_week     poutcome
# 0         thu  nonexistent
# 1         fri  nonexistent

# %% [markdown]
# ### Развернем EDA на категориальных колонках. А так же методы фильтрации на вещественных. Вдруг от каких-то получится избавиться заранее, чтобы не плодить огромный датасет!

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
### Есть ли пропуски?

df.describe()
# Out:
#                age      campaign         pdays      previous  emp_var_rate  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406      2.567593    962.475454      0.172963      0.081886
# std       10.42125      2.770014    186.910907      0.494901      1.570960
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons_price_idx  cons_conf_idx     euribor3m   nr_employed             y
# count    41188.000000   41188.000000  41188.000000  41188.000000  41188.000000
# mean        93.575664     -40.502600      3.621291   5167.035911      0.112654
# std          0.578840       4.628198      1.734447     72.251528      0.316173
# min         92.201000     -50.800000      0.634000   4963.600000      0.000000
# 25%         93.075000     -42.700000      1.344000   5099.100000      0.000000
# 50%         93.749000     -41.800000      4.857000   5191.000000      0.000000
# 75%         93.994000     -36.400000      4.961000   5228.100000      0.000000
# max         94.767000     -26.900000      5.045000   5228.100000      1.000000

# %%
### Изучим корелляции вещественных признаков

corr = df[numeric_columns].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_69195_row0_col0, #T_69195_row1_col1, #T_69195_row2_col2, #T_69195_row3_col3, #T_69195_row4_col4, #T_69195_row5_col5, #T_69195_row6_col6, #T_69195_row7_col7, #T_69195_row8_col8, #T_69195_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_69195_row0_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_69195_row0_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_69195_row0_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_69195_row0_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_69195_row0_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_69195_row0_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_69195_row0_col7, #T_69195_row1_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_69195_row0_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_69195_row0_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_69195_row1_col0, #T_69195_row3_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_69195_row1_col2, #T_69195_row1_col7 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_69195_row1_col4, #T_69195_row6_col8 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_69195_row1_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_69195_row1_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_69195_row1_col8, #T_69195_row3_col9 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_69195_row1_col9, #T_69195_row4_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_69195_row2_col0, #T_69195_row2_col3, #T_69195_row2_col6, #T_69195_row3_col1, #T_69195_row3_col2, #T_69195_row3_col4, #T_69195_row3_col5, #T_69195_row3_col7, #T_69195_row3_col8, #T_69195_row8_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_69195_row2_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_69195_row2_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_69195_row2_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_69195_row2_col7 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_69195_row2_col8 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_69195_row2_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_69195_row3_col0, #T_69195_row9_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_69195_row4_col0, #T_69195_row5_col0, #T_69195_row7_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_69195_row4_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_69195_row4_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_69195_row4_col5 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_69195_row4_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_69195_row4_col7 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_69195_row4_col8 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_69195_row4_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_69195_row5_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_69195_row5_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_69195_row5_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_69195_row5_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_69195_row5_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_69195_row5_col7 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_69195_row5_col8 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_69195_row5_col9 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_69195_row6_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_69195_row6_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_69195_row6_col2 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_69195_row6_col3, #T_69195_row7_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_69195_row6_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_69195_row6_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_69195_row6_col7 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_69195_row6_col9 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_69195_row7_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_69195_row7_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_69195_row7_col2 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_69195_row7_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_69195_row7_col4 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_69195_row7_col5 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_69195_row7_col8, #T_69195_row8_col7 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_69195_row8_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_69195_row8_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_69195_row8_col2, #T_69195_row8_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_69195_row8_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_69195_row8_col4 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_69195_row8_col6 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_69195_row9_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_69195_row9_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_69195_row9_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_69195_row9_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_69195_row9_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_69195_row9_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_69195_row9_col7, #T_69195_row9_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_69195">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69195_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_69195_level0_col1" class="col_heading level0 col1" >campaign</th>
#       <th id="T_69195_level0_col2" class="col_heading level0 col2" >pdays</th>
#       <th id="T_69195_level0_col3" class="col_heading level0 col3" >previous</th>
#       <th id="T_69195_level0_col4" class="col_heading level0 col4" >emp_var_rate</th>
#       <th id="T_69195_level0_col5" class="col_heading level0 col5" >cons_price_idx</th>
#       <th id="T_69195_level0_col6" class="col_heading level0 col6" >cons_conf_idx</th>
#       <th id="T_69195_level0_col7" class="col_heading level0 col7" >euribor3m</th>
#       <th id="T_69195_level0_col8" class="col_heading level0 col8" >nr_employed</th>
#       <th id="T_69195_level0_col9" class="col_heading level0 col9" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69195_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_69195_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_69195_row0_col1" class="data row0 col1" >0.004594</td>
#       <td id="T_69195_row0_col2" class="data row0 col2" >-0.034369</td>
#       <td id="T_69195_row0_col3" class="data row0 col3" >0.024365</td>
#       <td id="T_69195_row0_col4" class="data row0 col4" >-0.000371</td>
#       <td id="T_69195_row0_col5" class="data row0 col5" >0.000857</td>
#       <td id="T_69195_row0_col6" class="data row0 col6" >0.129372</td>
#       <td id="T_69195_row0_col7" class="data row0 col7" >0.010767</td>
#       <td id="T_69195_row0_col8" class="data row0 col8" >-0.017725</td>
#       <td id="T_69195_row0_col9" class="data row0 col9" >0.030399</td>
#     </tr>
#     <tr>
#       <th id="T_69195_level0_row1" class="row_heading level0 row1" >campaign</th>
#       <td id="T_69195_row1_col0" class="data row1 col0" >0.004594</td>
#       <td id="T_69195_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_69195_row1_col2" class="data row1 col2" >0.052584</td>
#       <td id="T_69195_row1_col3" class="data row1 col3" >-0.079141</td>
#       <td id="T_69195_row1_col4" class="data row1 col4" >0.150754</td>
#       <td id="T_69195_row1_col5" class="data row1 col5" >0.127836</td>
#       <td id="T_69195_row1_col6" class="data row1 col6" >-0.013733</td>
#       <td id="T_69195_row1_col7" class="data row1 col7" >0.135133</td>
#       <td id="T_69195_row1_col8" class="data row1 col8" >0.144095</td>
#       <td id="T_69195_row1_col9" clas

# %%
### Изобразим в виде Тепловой карты

import seaborn as sns

fig = plt.figure()

fig.set_size_inches(16, 10)

sns.heatmap(df[numeric_columns].corr(), 
            xticklabels=numeric_columns,
            yticklabels=numeric_columns,
            cmap='BrBG',
            vmin=-1,
            vmax=1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\e.tarasov\Personal\KC\startml\1_lesson_10\Practice_10.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/e.tarasov/Personal/KC/startml/1_lesson_10/Practice_10.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> ### Изобразим в виде Тепловой карты
# ----> <a href='vscode-notebook-cell:/c%3A/Users/e.tarasov/Personal/KC/startml/1_lesson_10/Practice_10.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/c%3A/Users/e.tarasov/Personal/KC/startml/1_lesson_10/Practice_10.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> fig = plt.figure()
#       <a href='vscode-notebook-cell:/c%3A/Users/e.tarasov/Personal/KC/startml/1_lesson_10/Practice_10.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> fig.set_size_inches(16, 10)
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
### Секретные функции для фильтрации признаков

def get_redundant_pairs(df):
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(df[numeric_columns], 10))
# Out:
# Top Absolute Correlations
# emp_var_rate    euribor3m         0.972245
# euribor3m       nr_employed       0.945154
# emp_var_rate    nr_employed       0.906970
#                 cons_price_idx    0.775334
# cons_price_idx  euribor3m         0.688230
# pdays           previous          0.587514
# cons_price_idx  nr_employed       0.522034
# previous        nr_employed       0.501333
#                 euribor3m         0.454494
#                 emp_var_rate      0.420489
# dtype: float64

# %%
test = df[numeric_columns].drop(['emp_var_rate', 'euribor3m'], axis=1)
get_top_abs_correlations(test, 10)
# Out:
# pdays           previous          0.587514
# cons_price_idx  nr_employed       0.522034
# previous        nr_employed       0.501333
# pdays           nr_employed       0.372605
# nr_employed     y                 0.354678
# pdays           y                 0.324914
# previous        y                 0.230181
#                 cons_price_idx    0.203130
# campaign        nr_employed       0.144095
# cons_price_idx  y                 0.136211
# dtype: float64

# %%
df = df.drop(['emp_var_rate', 'euribor3m'], axis=1)
numeric_columns = numeric_columns.drop(['emp_var_rate', 'euribor3m'])

# %%
### Посмотрим на квазиконстантые признаки

from sklearn.feature_selection import VarianceThreshold


cutter = VarianceThreshold(threshold=0.1)
cutter.fit(df[numeric_columns])

cutter.get_feature_names_out()
# Out:
# array(['age', 'campaign', 'pdays', 'previous', 'cons_price_idx',
#        'cons_conf_idx', 'nr_employed'], dtype=object)

# %%
numeric_columns
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'cons_price_idx',
#        'cons_conf_idx', 'nr_employed', 'y'],
#       dtype='object')

# %%
### Еще один способ, как в задаче классификации без построения модели
### оценить важность вещественных признаков- с помощью ящиков с усами!
### Только теперь немного "наоборот", представляя таргет как категорию
### А значения, распределение которых хотим сравнивать, окажутся нашими фичами
import seaborn as sns

num_col = ['age', 'nr_employed']

for col in num_col:
    
    fig = plt.figure()
    fig.set_size_inches(16, 10)
    
    sns.boxplot(y=col, x=df['y'].astype('category'), data=df)
    
    plt.show()

# %%
### Посмотрим на распределение категорий среди разных таргетов

df.describe(include='object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    41188    41188              41188   41188   41188  41188     41188
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome
# count   41188       41188        41188
# unique     10           5            3
# top       may         thu  nonexistent
# freq    13769        8623        35563

# %%
### Гистограммы распределений в разных классах

for col in categorical_columns:
    g = sns.catplot(x=col, kind='count', col='y', data=df, sharey=False)
    g.set_xticklabels(rotation=60)

# %%
df = df.drop(['loan', 'housing', 'marital'], axis=1)
categorical_columns = categorical_columns.drop(['loan', 'housing', 'marital'])

# %%
df.head().shape
# Out:
# (5, 15)

# %% [markdown]
# ### Закодируем оставшиеся категориальные фичи!

# %%
### Посмотрим, какие можно кодировать с помощью one-hot метода, 
### а для каких лучше посчитать счетчики!

df.describe(include='object')
# Out:
#            job          education default   contact  month day_of_week  \
# count    41188              41188   41188     41188  41188       41188
# unique      12                  8       3         2     10           5
# top     admin.  university.degree      no  cellular    may         thu
# freq     10422              12168   32588     26144  13769        8623
#
#            poutcome
# count         41188
# unique            3
# top     nonexistent
# freq          35563

# %%
for col in categorical_columns:
    
    ### К колонкам с маленькой размерностью применим one-hot
    if df[col].nunique() < 5:
        one_hot = pd.get_dummies(df[col], prefix=col, drop_first=True)
        df = pd.concat((df.drop(col, axis=1), one_hot), axis=1)
        
    ### К остальным - счетчики
    else:
        mean_target = df.groupby(col)['y'].mean()
        df[col] = df[col].map(mean_target)

# %%
df.head()
# Out:
#    age       job  education     month  day_of_week  campaign  pdays  previous  \
# 0   44  0.068943   0.102490  0.106021     0.121188         1    999         0
# 1   53  0.108260   0.145003  0.101439     0.108087         1    999         0
# 2   28  0.112175   0.137245  0.105115     0.121188         3      6         2
# 3   39  0.081381   0.108355  0.204787     0.108087         2    999         0
# 4   55  0.252326   0.102490  0.106021     0.108087         1      3         1
#
#    cons_price_idx  cons_conf_idx  nr_employed  y  default_unknown  \
# 0          93.444          -36.1       5228.1  0             True
# 1          93.200          -42.0       5195.8  0            False
# 2          94.055          -39.8       4991.6  1            False
# 3          93.075          -47.1       5099.1  0            False
# 4          92.201          -31.4       5076.2  1            False
#
#    default_yes  contact_telephone  poutcome_nonexistent  poutcome_success
# 0        False              False                  True             False
# 1        False              False                  True             False
# 2        False              False                 False              True
# 3        False              False                  True             False
# 4        False              False                 False              True

# %%
X = df.drop('y', axis=1)
Y = df['y']

# %% [markdown]
# ### Обучим Логистическую регрессию!

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, 
                                                    random_state=0, 
                                                    test_size=0.2)

# %%
X_train.shape[0], X_test.shape[0]
# Out:
# (32950, 8238)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

pipe = Pipeline([('scaler', StandardScaler()),
                 ('LR', LogisticRegression(penalty='none'))])

pipe.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('LR', LogisticRegression(penalty='none'))])

# %%
### Pipeline автоматом для классификации отображает accuracy

pipe.score(X_test, Y_test)
# Out:
# 0.9011896091284293

# %%
X_test.head(1)
# Out:
#        age       job  education     month  day_of_week  campaign  pdays  \
# 15500   51  0.068943   0.078246  0.204787     0.099483         4    999
#
#        previous  cons_price_idx  cons_conf_idx  nr_employed  default_unknown  \
# 15500         0          93.075          -47.1       5099.1            False
#
#        default_yes  contact_telephone  poutcome_nonexistent  poutcome_success
# 15500        False              False                  True             False

# %%
### Чтобы предсказать вероятности соответственно классам
### Обратимся к аттрибуту classes_ и к методу predict_proba
### А чтобы понять уверенность модели, воспользуемся методом
### decision_function

print(pipe.classes_)

print(pipe.predict(X_test.head(1)))

print(pipe.predict_proba(X_test.head(1)))

print(pipe.decision_function(X_test.head(2)))
# Out:
# [0 1]
# [0]
# [[0.88133713 0.11866287]]
# [-2.00515374 -2.25746979]

# %%
### Константное предсказание на тесте

np.mean(Y_test == 0)
# Out:
# 0.8891721291575625

# %%
df['y'].value_counts()
# Out:
# 0    36548
# 1     4640
# Name: y, dtype: int64
