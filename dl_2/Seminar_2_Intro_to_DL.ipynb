# %% [markdown]
# # Оптимизация нейронных сетей. Метод обратного распространения ошибки (ноутбук)
#
# > Узнаем как устроена оптимизация нейронных сетей. Оптимизация в `PyTorch`.

# %% [markdown]
# ## План ноутбука
#
# 1. Высокоуровневое API для обучение нейросетей в `PyTorch`
# 2. Обучение первой нейросети в `PyTorch`

# %% [markdown]
# ## Высокоуровневое API для обучение нейросетей в `PyTorch`

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Создание объекта нейросети

# %%
net = nn.Sequential(
    nn.Linear(700, 500),
    nn.ReLU(),
    nn.Linear(500, 200),
    nn.ReLU(),
    nn.Linear(200, 10)
)

# %%
net
# Out:
# Sequential(
#   (0): Linear(in_features=700, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=500, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=10, bias=True)
# )

# %%
from collections import OrderedDict

net = nn.Sequential(
    OrderedDict(
        [
            ('linear1', nn.Linear(700, 500)),
            ('relu1', nn.ReLU()),
            ('linear2', nn.Linear(500, 200)),
            ('relu2', nn.ReLU()),
            ('linear3', nn.Linear(200, 10))
        ]
    )
)

# %%
net.linear1
# Out:
# Linear(in_features=700, out_features=500, bias=True)

# %%
input_tensor = torch.rand(10, 700)

net(input_tensor).shape
# Out:
# torch.Size([10, 10])

# %%
class CustomTaskNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear1 = nn.Linear(700, 500)
        self.linear2 = nn.Linear(500, 200)
        self.linear3 = nn.Linear(200, 10)

        self.activation = nn.ReLU()

    def forward(self, x):
        output = self.activation(self.linear1(x))
        output = self.activation(self.linear2(output))
        output = self.linear3(output)

        return output

# %%
net = CustomTaskNetwork()

net(input_tensor).shape
# Out:
# torch.Size([10, 10])

# %%
net.to()
# Out:
# CustomTaskNetwork(
#   (linear1): Linear(in_features=700, out_features=500, bias=True)
#   (linear2): Linear(in_features=500, out_features=200, bias=True)
#   (linear3): Linear(in_features=200, out_features=10, bias=True)
#   (activation): ReLU()
# )

# %%
net.train()
net.eval()

net.requires_grad_()
# Out:
# CustomTaskNetwork(
#   (linear1): Linear(in_features=700, out_features=500, bias=True)
#   (linear2): Linear(in_features=500, out_features=200, bias=True)
#   (linear3): Linear(in_features=200, out_features=10, bias=True)
#   (activation): ReLU()
# )

# %%
net.parameters()
# Out:
# <generator object Module.parameters at 0x0000018EBB47F3E0>

# %%
net.state_dict()
# Out:
# OrderedDict([('linear1.weight',
#               tensor([[ 0.0242,  0.0078,  0.0109,  ..., -0.0316, -0.0249, -0.0182],
#                       [ 0.0267,  0.0091,  0.0039,  ...,  0.0254, -0.0077,  0.0101],
#                       [-0.0214,  0.0178, -0.0324,  ..., -0.0281,  0.0341,  0.0296],
#                       ...,
#                       [-0.0242,  0.0039,  0.0304,  ..., -0.0248, -0.0278, -0.0223],
#                       [ 0.0284, -0.0154,  0.0161,  ..., -0.0215,  0.0067,  0.0286],
#                       [ 0.0375, -0.0180,  0.0010,  ..., -0.0176, -0.0225,  0.0093]])),
#              ('linear1.bias',
#               tensor([-2.8662e-02,  3.7251e-02,  2.0614e-02,  2.4399e-02,  1.6917e-02,
#                        1.2851e-02,  1.4385e-02, -2.8415e-02, -2.9006e-02, -1.3612e-02,
#                       -1.7165e-02, -1.9116e-02, -1.8488e-02, -3.5874e-02, -1.0187e-02,
#                       -8.6642e-03,  1.9877e-02, -1.6024e-02, -1.2617e-02, -2.4848e-02,
#                        5.0609e-03,  2.9533e-02,  1.6946e-02, -3.5477e-02,  2.9568e-02,
#                       -3.5034e-02, -2.6297e-03,  2.6335e-02,  5.6391e-03, -3.4192e-02,
#                       -2.0464e-02,  3.1202e-02,  3.8026e-03,  1.6090e-02,  2.5785e-02,
#                        0.0062, -0.0072,  0.0127,  0.0400, -0.0138, -0.0177, -0.0235, -0.0022,
#                        0.0339, -0.0010,  0.0072, -0.0015,  0.0082, -0.0305,  0.0348, -0.0414,
#                       -0.0196, -0.0411, -0.0130, -0.0095, -0.0108,  0.0091,  0.0225,  0.0058,
#                       -0.0336,  0.0228,  0.0025,  0.0035,  0.0324, -0.0008,  0.0155,  0.0266,
#                        0.0383,  0.0229, -0.0363, -0.0418,  0.0320, -0.0353,  0.0035,  0.0333,
#                        0.0029,  0.0106, -0.0378,  0.0043, -0.0102,  0.0268,  0.0252,  0.0024,
#                       -0.0084, -0.0232,  0.0255,  0.0327,  0.0015, -0.0050,  0.0187, -0.0379,
#                       -0.0040, -0.0285, -0.0128, -0.0011, -0.0314,  0.0014,  0.0272, -0.0422,
#                       -0.0168, -0.0299,  0.0321, -0.0154, -0.0108,  0.0115,  0.0054,  0.0104,
#                       -0.0108,  0.0387,  0.0338, -0.0057,  0.0371,  0.0330,  0.0353,  0.0121,
#                        0.0264, -0.0407,  0.0280, -0.0295,  0.0314, -0.0318, -0.0168, -0.0371,
#                        0.0351, -0.0334, -0.0353, -0.0006, -0.0158,  0.0239, -0.0435,  0.0416,
#                       -0.0309,  0.0103,  0.0090, -0.0375, -0.0030,  0.0167,  0.0427, -0.0211,
#                        0.0315, -0.0013, -0.0433,  0.0002, -0.0108,  0.0165,  0.0022, -0.0310,
#                        0.0106,  0.0404, -0.0398, -0.0365, -0.0336, -0.0251, -0.0409,  0.0374,
#                       -0.0208, -0.0368, -0.0313,  0.0321,  0.0418,  0.0155, -0.0439, -0.0075,
#                        0.0051,  0.0302,  0.0376, -0.0003, -0.0134, -0.0110, -0.0301, -0.0307,
#                       -0.0112, -0.0158,  0.0072, -0.0121,  0.0092, -0.0040,  0.0072, -0.0317,
#                       -0.0210,  0.0070,  0.0375, -0.0070, -0.0063, -0.0291, -0.0350, -0.0394,
#                       -0.0377,  0.0281, -0.0446, -0.0328, -0.0406,  0.0031,  0.0249,  0.0179,
#                       -0.0100,  0.0445, -0.0217,  0.0247, -0.0126,  0.0307, -0.0157, -0.0446,
#                       -0.0201,  0.0167, -0.0009, -0.0039,  0.0356,  0.0423,  0.0335,  0.0054,
#                        0.0423,  0.0153, -0.0404,  0.0367, -0.0175,  0.0120,  0.0311, -0.0385])),
#              ('linear3.weight',
#               tensor([[ 0.0457,  0.0088,  0.0599,  ...,  0.0582, -0.0599, -0.0295],
#                       [-0.0584,  0.0184,  0.0550,  ...,  0.0185,  0.0546, -0.0265],
#                       [-0.0465,  0.0470, -0.0138,  ...,  0.0608,  0.0624, -0.0544],
#                       ...,
#                       [ 0.0528,  0.0382,  0.0245,  ..., -0.0110,  0.0614,  0.0374],
#                       [ 0.0445, -0.0608,  0.0342,  ..., -0.0187, -0.0081, -0.0163],
#                       [ 0.0643,  0.0132, -0.0383,  ...,  0.0122,  0.0168, -0.0565]])),
#              ('linear3.bias',
#               tensor([-0.0677, -0.0633, -0.0230,  0.0118,  0.0116,  0.0099,  0.0312,  0.0590,
#                       -0.0201,  0.0250]))])

# %%
net.load_state_dict(net.state_dict())
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Оптимизаторы

# %%
from torch import optim

# %%
optim.SGD, optim.Adam
# Out:
# (torch.optim.sgd.SGD, torch.optim.adam.Adam)

# %%
optimizer = optim.Adam(net.parameters(), lr=0.0001)

# %%
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# )

# %%
optimizer = optim.SGD(
    [
        {'params': net.linear1.parameters()},
        {'params': net.linear2.parameters(), 'lr': 1e-3}
    ],
    lr=1e-2,
    momentum=0.9
)

# %%
optimizer.step()

# %%
optimizer.zero_grad()

# %% [markdown]
# ### Функции потерь

# %%
nn.L1Loss, nn.MSELoss, nn.CrossEntropyLoss
# Out:
# (torch.nn.modules.loss.L1Loss,
#  torch.nn.modules.loss.MSELoss,
#  torch.nn.modules.loss.CrossEntropyLoss)

# %%
loss = nn.MSELoss()

# %%
input = torch.randn(3, 5, requires_grad=True)
target = torch.randn(3, 5)

output = loss(input, target)

print(output)

output.backward()
# Out:
# tensor(2.5575, grad_fn=<MseLossBackward0>)

# %%
input.grad
# Out:
# tensor([[ 0.1323,  0.0927,  0.4579, -0.3076,  0.1541],
#         [-0.1841, -0.3431,  0.0129, -0.0326, -0.2800],
#         [ 0.1487, -0.1870,  0.1929,  0.0435, -0.0201]])

# %% [markdown]
# ### Датасеты и даталоадеры

# %%
from torch.utils.data import Dataset
from torch.utils.data import TensorDataset

# %%
n_features = 2
n_objects = 300

torch.manual_seed(0);

# %%
w_true = torch.randn(n_features)

X = (torch.rand(n_objects, n_features) - 0.5) * 10
X *= (torch.arange(n_features) * 2 + 1)
Y = (X @ w_true + torch.randn(n_objects)).unsqueeze(1)

# %%
dataset = TensorDataset(X, Y)

# %%
dataset[7]
# Out:
# (tensor([-3.3897, -6.5319]), tensor([-3.7483]))

# %%
X[7], Y[7]
# Out:
# (tensor([-3.3897, -6.5319]), tensor([-3.7483]))

# %%
class CustomDataset(Dataset):
    def __init__(self, w_true, n_features, n_objects):
        self.X = (torch.rand(n_objects, n_features) - 0.5) * 10
        self.X *= (torch.arange(n_features) * 2 + 1)
        self.Y = self.X @ w_true + torch.randn(n_objects)

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, item):
        return self.X[item], self.Y[item]

# %%
dataset = CustomDataset(w_true, n_features, n_objects)

# %%
from torch.utils.data import DataLoader

# %%
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
for x, y in loader:
    print(x.shape)
# Out:
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])

# %%
X.shape
# Out:
# torch.Size([300, 2])

# %% [markdown]
# ### Общая структура обучения модели

# %% [markdown]
# model.train()
#
# for x, y in dataloader:
#
#     optimizer.zero_grad()
#
#     output = model(x)
#
#     loss = loss_fn(output, y)
#
#     loss.backward()
#
#     optimizer.step()

# %% [markdown]
# ## Обучение первой нейросети в `PyTorch`

# %%
class CustomTaskNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(n_features, 1)

    def forward(self, x):
        return self.linear(x)

net = CustomTaskNetwork()

optimizer = optim.Adam(net.parameters(), lr=1e-1)

loss_fn = nn.MSELoss()

dataset = TensorDataset(X, Y)

loader = DataLoader(dataset, batch_size=4, shuffle=True)

w_list = torch.empty(len(loader) + 1, n_features)

# %%
net.train()

for i, (x, y) in enumerate(loader):
    w_list[i] = net.linear.weight.detach().clone()

    optimizer.zero_grad()

    output = net(x)

    loss = loss_fn(output, y)

    print(f'MSE на шаге {i} {loss.item():.5f}')

    loss.backward()

    optimizer.step()

w_list[len(loader)] = net.linear.weight.detach().clone()
# Out:
# MSE на шаге 0 28.63088
# MSE на шаге 1 45.38396
# MSE на шаге 2 1.64545
# MSE на шаге 3 30.87534
# MSE на шаге 4 45.28118
# MSE на шаге 5 11.27283
# MSE на шаге 6 9.16029
# MSE на шаге 7 14.66862
# MSE на шаге 8 13.91990
# MSE на шаге 9 14.74506
# MSE на шаге 10 10.66703
# MSE на шаге 11 12.45725
# MSE на шаге 12 14.94521
# MSE на шаге 13 10.00435
# MSE на шаге 14 2.04556
# MSE на шаге 15 9.38098
# MSE на шаге 16 9.90906
# MSE на шаге 17 2.16970
# MSE на шаге 18 1.53581
# MSE на шаге 19 5.15861
# MSE на шаге 20 0.65541
# MSE на шаге 21 2.19203
# MSE на шаге 22 1.33867
# MSE на шаге 23 1.24042
# MSE на шаге 24 1.43382
# MSE на шаге 25 2.31887
# MSE на шаге 26 0.67618
# MSE на шаге 27 2.36088
# MSE на шаге 28 1.00729
# MSE на шаге 29 0.30867
# MSE на шаге 30 3.10811
# MSE на шаге 31 1.03187
# MSE на шаге 32 1.54535
# MSE на шаге 33 0.91494
# MSE на шаге 34 0.71947
# MSE на шаге 35 1.57248
# MSE на шаге 36 1.05323
# MSE на шаге 37 1.56655
# MSE на шаге 38 1.97591
# MSE на шаге 39 1.25570
# MSE на шаге 40 2.83284
# MSE на шаге 41 3.17145
# MSE на шаге 42 1.99665
# MSE на шаге 43 0.17588
# MSE на шаге 44 1.93378
# MSE на шаге 45 1.50835
# MSE на шаге 46 0.19229
# MSE на шаге 47 2.37159
# MSE на шаге 48 1.79891
# MSE на шаге 49 1.32140
# MSE на шаге 50 0.50359
# MSE на шаге 51 0.89421
# MSE на шаге 52 0.33572
# MSE на шаге 53 0.40519
# MSE на шаге 54 1.37717
# MSE на шаге 55 0.33658
# MSE на шаге 56 0.61777
# MSE на шаге 57 0.37216
# MSE на шаге 58 0.23090
# MSE на шаге 59 1.73778
# MSE на шаге 60 0.77039
# MSE на шаге 61 0.84526
# MSE на шаге 62 1.67799
# MSE на шаге 63 0.45080
# MSE на шаге 64 0.23165
# MSE на шаге 65 0.40536
# MSE на шаге 66 1.60400
# MSE на шаге 67 0.48095
# MSE на шаге 68 0.92880
# MSE на шаге 69 1.30958
# MSE на шаге 70 1.90104
# MSE на шаге 71 0.78089
# MSE на шаге 72 0.77918
# MSE на шаге 73 0.53447
# MSE на шаге 74 2.56288

# %%
from plot_trajectory import plot_trajectory

plot_trajectory(
    w_list.numpy(),
    w_true.numpy(),
    X.numpy(),
    Y.squeeze(1).numpy(),
    'Mini-batch градиентный спуск'
)

# %%
num_epochs = 5

w_list = torch.empty(len(loader) * num_epochs + 1, n_features)

net = CustomTaskNetwork()

optimizer = optim.Adam(net.parameters(), lr=1e-1)

# %%
net.train()

for epoch in range(num_epochs):
    total_loss = 0

    for i, (x, y) in enumerate(loader):
        w_list[i + epoch * len(loader)] = net.linear.weight.detach().clone()

        optimizer.zero_grad()

        output = net(x)

        loss = loss_fn(output, y)

        total_loss += loss.item()

        loss.backward()

        optimizer.step()

    total_loss /= len(loader)

    print(f'MSE после эпохи {epoch} {total_loss:.5f}')

w_list[len(loader) * num_epochs] = net.linear.weight.detach().clone()
# Out:
# MSE после эпохи 0 6.04939
# MSE после эпохи 1 1.08135
# MSE после эпохи 2 1.09777
# MSE после эпохи 3 1.24916
# MSE после эпохи 4 1.12345

# %%
from plot_trajectory import plot_trajectory

plot_trajectory(
    w_list.numpy(),
    w_true.numpy(),
    X.numpy(),
    Y.squeeze(1).numpy(),
    'Mini-batch градиентный спуск'
)
